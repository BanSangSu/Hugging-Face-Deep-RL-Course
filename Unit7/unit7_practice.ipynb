# %% [markdown]
# **All code in this unit is I did.**

# %%
# !git clone https://github.com/Unity-Technologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 90748, done.
# remote: Counting objects: 100% (1637/1637), done.
# remote: Compressing objects: 100% (746/746), done.
# remote: Total 90748 (delta 973), reused 1373 (delta 820), pack-reused 89111
# Receiving objects: 100% (90748/90748), 2.87 GiB | 20.68 MiB/s, done.
# Resolving deltas: 100% (66101/66101), done.
# Updating files: 100% (2173/2173), done.

# %%
import os
os.getcwd()
# Out:
# '/home/fds/Dev/Pytorch'

# %%
# %cd ml-agents
# Out:
# /home/fds/Dev/Pytorch/ml-agents

# %%
# !pip install -e ./ml-agents-envs
# !pip install -e ./ml-agents
# Out:
# /home/fds/Dev/Pytorch/ml-agents
# Obtaining file:///home/fds/Dev/Pytorch/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 2.5 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 7.8 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 35.0 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for pettingzoo: filename=PettingZoo-1.15.0-py3-none-any.whl size=875631 sha256=71f28cfd7bec76aa3db207558bff128fb105b32dbaab7d636fe525ad3517127e
#   Stored in directory: /home/fds/.cache/pip/wheels/e3/35/ac/76984cb1c12902d190c818d57c43d25c3f9281591a640ccd13
# ...

# %%
# !pip install onnx==1.12.0
# !pip install protobuf==3.19.6
# Out:
# ...
#   Using cached protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.0
#     Uninstalling protobuf-3.19.0:
#       Successfully uninstalled protobuf-3.19.0
# ...

# %% [markdown]
# My **SoccerTwos.yaml**
# ```python
# behaviors:
#   SoccerTwos:
#     trainer_type: poca
#     hyperparameters:
#       batch_size: 2048
#       buffer_size: 20480
#       learning_rate: 0.0003
#       beta: 0.005
#       epsilon: 0.2
#       lambd: 0.95
#       num_epoch: 3
#       learning_rate_schedule: constant
#     network_settings:
#       normalize: false
#       hidden_units: 512
#       num_layers: 2
#       vis_encode_type: simple
#     reward_signals:
#       extrinsic:
#         gamma: 0.99
#         strength: 1.0
#     keep_checkpoints: 5
#     max_steps: 5000000
#     time_horizon: 1000
#     summary_freq: 10000
#     self_play:
#       save_steps: 50000
#       team_change: 200000
#       swap_steps: 2000
#       window: 10
#       play_against_latest_model_ratio: 0.5
#       initial_elo: 1200.0
# ```

# %%
# !chmod -R 755 ./training-envs-executables/SoccerTwos/

# %%
# !mlagents-learn ./config/poca/MySoccerTwos.yaml --env=./training-envs-executables/SoccerTwos/SoccerTwos --run-id="SoccerTwos" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.31.0.dev0,
#   ml-agents-envs: 0.31.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.11.0+cu102
# [INFO] Connected to Unity environment with package version 2.3.0-exp.3 and communication version 1.5.0
# ...

# %%
# # Run in console
# huggingface-cli login

# %%
# !mlagents-push-to-hf --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="BanUrsus/poca-SoccerTwos" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your SoccerTwos into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SoccerTwos to the Hugging Face Hub
# SoccerTwos-48499956.onnx:   0%|                     | 0.00/1.76M [00:00<?, ?B/s]
# SoccerTwos-48499956.pt:   0%|                       | 0.00/28.4M [00:00<?, ?B/s]
#
# SoccerTwos-48999924.onnx:   0%|                     | 0.00/1.76M [00:00<?, ?B/s]
#
#
# SoccerTwos-48999924.pt:   0%|                       | 0.00/28.4M [00:00<?, ?B/s]
#
#
#
# Upload 13 LFS files:   0%|                               | 0/13 [00:00<?, ?it/s]
#
#
#
#
# SoccerTwos-49499992.onnx:   0%|                     | 0.00/1.76M [00:00<?, ?B/s]
# SoccerTwos-48499956.pt:   0%|              | 8.19k/28.4M [00:00<38:41, 12.2kB/s]
#
# SoccerTwos-48499956.onnx:   0%|            | 8.19k/1.76M [00:00<02:25, 12.0kB/s]
#
#
# ...
